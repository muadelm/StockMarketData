# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# C:\Users\M.Amer\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
ptr = yf.Ticker('PTR')

# %%
ptr.info
# Out:
# {'zip': '100007',
#  'sector': 'Energy',
#  'fullTimeEmployees': 432003,
#  'longBusinessSummary': "PetroChina Company Limited, together with its subsidiaries, engages in a range of petroleum related products, services, and activities in Mainland China and internationally. It operates through Exploration and Production, Refining and Chemicals, Marketing, and Natural Gas and Pipeline segments. The Exploration and Production segment engages in the exploration, development, production, and marketing of crude oil and natural gas. The Refining and Chemicals segment refines crude oil and petroleum products; and produces and markets primary petrochemical products, derivative petrochemical products, and other chemical products. The Marketing segment is involved in marketing of refined products and trading business. The Natural Gas and Pipeline segment engages in the transmission of natural gas, crude oil, and refined products; and sale of natural gas. As of December 31, 2020, the company had a total length of 31,151 km, including 22,555 km of natural gas pipelines, 7,190 km of crude oil pipelines, and 1,406 km of refined product pipelines. The company is also involved in the exploration, development, and production of oil sands and coalbed methane; trading of crude oil and petrochemical products; storage, chemical engineering, storage facilities, service station, and transportation facilities and related businesses; and production and sales of basic and derivative chemical, and other chemical products. The company was founded in 1999 and is headquartered in Beijing, the People's Republic of China. PetroChina Company Limited is a subsidiary of China National Petroleum Corporation.",
#  'city': 'Beijing',
#  'phone': '86 10 5998 2622',
#  'country': 'China',
#  'companyOfficers': [],
#  'website': 'https://www.petrochina.com.cn',
#  'maxAge': 1,
#  'address1': '9 Dongzhimen North Street',
#  'fax': '86 10 6209 9557',
#  'industry': 'Oil & Gas Integrated',
#  'address2': 'Dongcheng District',
#  'ebitdaMargins': 0.12197,
#  'profitMargins': 0.0352,
#  'grossMargins': 0.32604998,
#  'operatingCashflow': 382019010560,
#  'revenueGrowth': 0.375,
#  'operatingMargins': 0.03975,
#  'ebitda': 291264987136,
#  'targetLowPrice': 50.5,
#  'recommendationKey': 'buy',
#  'grossProfits': 666039000000,
#  'freeCashflow': 153852624896,
#  'targetMedianPrice': 63.2,
#  'currentPrice': 52.26,
#  'earningsGrowth': -0.447,
#  'currentRatio': 0.899,
#  'returnOnAssets': 0.0232,
#  'numberOfAnalystOpinions': 3,
#  'targetMeanPrice': 65.9,
#  'debtToEquity': 36.514,
#  'returnOnEquity': 0.077010006,
#  'targetHighPrice': 84,
#  'totalCash': 205005996032,
#  'totalDebt': 507007991808,
#  'totalRevenue': 2388007059456,
#  'totalCashPerShare': 112.012,
#  'financialCurrency': 'CNY',
#  'revenuePerShare': 1303.7,
#  'quickRatio': 0.487,
#  'recommendationMean': 2,
#  'exchange': 'NYQ',
#  'shortName': 'PetroChina Company Limited',
#  'longName': 'PetroChina Company Limited',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'PTR',
#  'messageBoardId': 'finmb_121373',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 0.227,
#  'beta3Year': None,
#  'enterpriseToEbitda': 1.858,
#  '52WeekChange': 0.6643467,
#  'morningStarRiskRating': None,
#  'forwardEps': 7.92,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 1830210048,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 680.6,
#  'sharesShort': 219527,
#  'sharesPercentSharesOut': 0.0001,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.02167,
#  'netIncomeToCommon': 84065001472,
#  'trailingEps': 7.1,
#  'lastDividendValue': 2.01,
#  'SandP52WeekChange': 0.14680505,
#  'priceToBook': 0.07678519,
#  'heldPercentInsiders': 0,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 1.58,
#  'sharesShortPreviousMonthDate': 1639526400,
#  'floatShares': 291332792,
#  'beta': 0.774504,
#  'enterpriseValue': 541202350080,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1631059200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.448,
#  'priceToSalesTrailing12Months': 0.06255555,
#  'dateShortInterest': 1642118400,
#  'pegRatio': -0.57,
#  'ytdReturn': None,
#  'forwardPE': 6.5984845,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 255154,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 52.61,
#  'regularMarketOpen': 52.8,
#  'twoHundredDayAverage': 45.30755,
#  'trailingAnnualDividendYield': 0.0041436986,
#  'payoutRatio': 0.48,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 53,
#  'navPrice': None,
#  'averageDailyVolume10Day': 217720,
#  'regularMarketPreviousClose': 52.61,
#  'fiftyDayAverage': 46.9588,
#  'trailingAnnualDividendRate': 0.218,
#  'open': 52.8,
#  'toCurrency': None,
#  'averageVolume10days': 217720,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 3.38,
#  'exDividendDate': 1631059200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 51.45,
#  'currency': 'USD',
#  'trailingPE': 7.3605633,
#  'regularMarketVolume': 245165,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 149383102464,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 169019,
#  'dayLow': 51.45,
#  'ask': 0,
#  'askSize': 1200,
#  'volume': 245165,
#  'fiftyTwoWeekHigh': 54.5,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 3.92,
#  'fiftyTwoWeekLow': 31.3,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0642,
#  'bidSize': 800,
#  'dayHigh': 53,
#  'regularMarketPrice': 52.26,
#  'logo_url': 'https://logo.clearbit.com/petrochina.com.cn'}

# %%
ptr.history()
# Out:
#                  Open       High        Low      Close  Volume  Dividends  \
# Date
# 2022-01-10  48.009998  48.009998  47.040001  47.169998  128000          0
# 2022-01-11  47.400002  48.630001  47.270000  48.619999  135400          0
# 2022-01-12  49.200001  50.389999  49.049999  49.599998  211400          0
# 2022-01-13  49.779999  50.220001  49.520000  49.570000  125400          0
# 2022-01-14  49.660000  50.700001  49.349998  50.639999  168800          0
# 2022-01-18  51.540001  52.349998  51.279999  51.619999  291000          0
# 2022-01-19  52.310001  52.480000  51.119999  51.590000  210300          0
# 2022-01-20  51.200001  51.279999  50.040001  50.090000  200300          0
# 2022-01-21  49.759998  50.419998  49.119999  49.639999  173400          0
# 2022-01-24  49.119999  49.639999  47.840000  49.279999  338500          0
# 2022-01-25  49.139999  51.369999  48.709999  51.060001  239300          0
# 2022-01-26  51.279999  51.720001  50.540001  51.230000  438800          0
# 2022-01-27  51.259998  51.799999  50.060001  50.509998  116400          0
# 2022-01-28  50.470001  50.529999  49.139999  49.689999  186100          0
# 2022-01-31  49.669998  50.279999  49.320000  49.490002  131200          0
# 2022-02-01  49.669998  50.630001  49.270000  50.369999  167400          0
# 2022-02-02  50.799999  51.270000  50.080002  50.830002  230200          0
# 2022-02-03  50.709999  51.160000  50.470001  50.970001  106200          0
# 2022-02-04  51.279999  52.419998  51.279999  51.759998  277700          0
# 2022-02-07  52.320000  52.959999  51.959999  52.610001  283900          0
# 2022-02-08  52.799999  53.000000  51.450001  52.259998  246000          0
#
#             Stock Splits
# Date
# 2022-01-10             0
# 2022-01-11             0
# 2022-01-12             0
# 2022-01-13             0
# 2022-01-14             0
# 2022-01-18             0
# 2022-01-19             0
# 2022-01-20             0
# 2022-01-21             0
# 2022-01-24             0
# 2022-01-25             0
# 2022-01-26             0
# 2022-01-27             0
# 2022-01-28             0
# 2022-01-31             0
# 2022-02-01             0
# 2022-02-02             0
# 2022-02-03             0
# 2022-02-04             0
# 2022-02-07             0
# 2022-02-08             0

# %%
ptr.actions #dividends and stock splits
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
quarter = ptr.quarterly_financials.T

# %%
ptr.major_holders
# Out:
#        0                                      1
# 0  0.00%        % of Shares Held by All Insider
# 1  2.17%       % of Shares Held by Institutions
# 2  2.17%        % of Float Held by Institutions
# 3    128  Number of Institutions Holding Shares

# %%
ptr.institutional_holders
# Out:
#                                           Holder  Shares Date Reported  \
# 0       Arrowstreet Capital, Limited Partnership  827922    2021-09-29
# 1                  Renaissance Technologies, LLC  728447    2021-09-29
# 2                              Marshall Wace LLP  261294    2021-09-29
# 3                   Dimensional Fund Advisors LP  241065    2021-09-29
# 4           Grantham Mayo Van Otterloo & Company  216100    2021-09-29
# 5             O'Shaughnessy Asset Management LLC  167822    2021-09-29
# 6                           Citadel Advisors LLC  143974    2021-09-29
# 7                Parametric Portfolio Associates  130053    2021-09-29
# 8  Connor Clark & Lunn Investment Management Ltd  129221    2021-09-29
# 9                        Toroso Investments, LLC  127192    2021-09-29
#
#     % Out     Value
# 0  0.0039  38730191
# 1  0.0035  34076750
# 2  0.0012  12223333
# 3  0.0011  11277020
# 4  0.0010  10109158
# 5  0.0008   7850713
# 6  0.0007   6735103
# 7  0.0006   6083879
# 8  0.0006   6044958
# 9  0.0006   5950041

# %%
ptr.balance_sheet.T
# Out:
#             Intangible Assets  Capital Surplus    Total Liab  \
#
# 2020-12-31       2.051600e+10     1.333080e+11  1.121505e+12
# 2019-12-31       1.958300e+10     1.333080e+11  1.288605e+12
# 2018-12-31       1.825800e+10              NaN  1.031986e+12
# 2017-12-31       1.766600e+10     1.333080e+11  1.023293e+12
#
#             Total Stockholder Equity  Minority Interest  Other Current Liab  \
#
# 2020-12-31              1.215158e+12       1.514630e+11        2.955010e+11
# 2019-12-31              1.230156e+12       2.141490e+11        2.551450e+11
# 2018-12-31              1.213783e+12       1.951080e+11        2.374840e+11
# 2017-12-31              1.193520e+12       1.877990e+11        2.390730e+11
#
#             Total Assets  Common Stock  Other Current Assets  \
#
# 2020-12-31  2.488126e+12  1.830210e+11          1.337540e+11
# 2019-12-31  2.732910e+12  1.830210e+11          8.310800e+10
# 2018-12-31  2.440877e+12  1.830210e+11          7.251000e+10
# 2017-12-31  2.404612e+12  1.830210e+11          5.830300e+10
#
#             Retained Earnings  ...  Other Stockholder Equity  \
#                                ...
# 2020-12-31       9.315120e+11  ...             -3.268300e+10
# 2019-12-31       9.404060e+11  ...             -2.657900e+10
# 2018-12-31       9.254080e+11  ...              1.053540e+11
# 2017-12-31       9.012060e+11  ...             -2.401500e+10
#
#             Property Plant Equipment  Total Current Assets  \
#
# 2020-12-31              1.661877e+12          4.867670e+11
# 2019-12-31              2.037960e+12          4.669130e+11
# 2018-12-31              1.709388e+12          4.382410e+11
# 2017-12-31              1.702813e+12          4.251620e+11
#
#             Long Term Investments  Net Tangible Assets  \
#
# 2020-12-31           2.606240e+11         1.186517e+12
# 2019-12-31           1.031150e+11         1.167765e+12
# 2018-12-31           9.320100e+10         1.153252e+12
# 2017-12-31           8.307600e+10         1.133920e+12
#
#             Short Term Investments  Net Receivables  Long Term Debt  \
#
# 2020-12-31            2.731900e+10     7.815100e+10    2.513790e+11
# 2019-12-31            2.425600e+10     9.085900e+10    2.908820e+11
# 2018-12-31            9.535000e+09     9.159700e+10    2.694220e+11
# 2017-12-31            1.334400e+10     8.606900e+10    2.898580e+11
#
#                Inventory  Accounts Payable
#
# 2020-12-31  1.285390e+11      1.131190e+11
# 2019-12-31  1.819210e+11      1.483350e+11
# 2018-12-31  1.775770e+11      1.230690e+11
# 2017-12-31  1.446690e+11      1.032010e+11
#
# [4 rows x 28 columns]

# %%
ptr.balance_sheet.T.plot(figsize = [12,40], subplots = True);

# %% [markdown]
# ### plotting blog post
# https://pandas.pydata.org/pandas-docs/version/0.9.1/visualization.html

# %%
ptr.cashflow
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                               -1.660900e+10 -1.624800e+10
# Change To Liabilities                      1.739700e+10  4.176200e+10
# Total Cashflows From Investing Activities -1.819860e+11 -3.329480e+11
# Net Borrowings                            -4.096400e+10  3.308400e+10
# Total Cash From Financing Activities      -9.940000e+10 -2.727600e+10
# Net Income                                 1.900600e+10  4.568200e+10
# Change In Cash                             3.222200e+10  4.550000e+08
# Effect Of Exchange Rate                   -4.967000e+09  1.069000e+09
# Total Cash From Operating Activities       3.185750e+11  3.596100e+11
# Depreciation                               2.213500e+11  2.323050e+11
# Other Cashflows From Investing Activities  8.710700e+10  4.412000e+09
# Dividends Paid                            -2.807800e+10 -3.027556e+10
# Change To Inventory                        4.364500e+10 -5.624000e+09
# Change To Account Receivables              1.475100e+10 -5.017000e+09
# Other Cashflows From Financing Activities -3.035800e+10 -2.967600e+10
# Change To Netincome                        2.426000e+09  5.050200e+10
# Capital Expenditures                      -2.483760e+11 -3.196860e+11
# Change To Operating Activities                      NaN  1.614950e+11
# Issuance Of Stock                                   NaN  2.640000e+09
#
#                                              2018-12-31    2017-12-31
# Investments                               -2.219000e+09 -1.691100e+10
# Change To Liabilities                      5.001900e+10  6.522900e+10
# Total Cashflows From Investing Activities -2.678120e+11 -2.435460e+11
# Net Borrowings                            -6.586000e+10 -4.386100e+10
# Total Cash From Financing Activities      -1.257030e+11 -9.472500e+10
# Net Income                                 5.303600e+10  2.279800e+10
# Change In Cash                            -3.774600e+10  2.484600e+10
# Effect Of Exchange Rate                    2.513000e+09 -3.538000e+09
# Total Cash From Operating Activities       3.532560e+11  3.666550e+11
# Depreciation                               2.307860e+11  2.328440e+11
# Other Cashflows From Investing Activities  4.769000e+09  6.401000e+09
# Dividends Paid                            -1.383627e+10 -1.596538e+10
# Change To Inventory                       -3.470500e+10  1.141000e+09
# Change To Account Receivables             -9.280000e+09 -2.779000e+09
# Other Cashflows From Financing Activities -3.247400e+10 -3.123800e+10
# Change To Netincome                        6.340000e+10  4.742200e+10
# Capital Expenditures                      -2.673100e+11 -2.292390e+11
# Change To Operating Activities             1.614950e+11  1.614950e+11
# Issuance Of Stock                          2.640000e+09  2.640000e+09

# %%
ptr.earnings
# Out:
#             Revenue     Earnings
# Year
# 2017  2015890000000  22798000000
# 2018  2374934000000  53036000000
# 2019  2516810000000  45682000000
# 2020  1933836000000  19006000000

# %%
ptr.sustainability

# %% [markdown]
# ## Multiple companies

# %%
company_list = ['PTR', 'TSLA', 'RDS-B', 'NIO', 'SNP', 'HAL', 'APPS', 'SE', 'NVDA', 'T', 'TELL', 'JNJ', 'SLB', 'PSX', 'TTE', 'BABA', 'DIDI', 'XOM']

# %%
companies = yf.download(company_list,group_by='Ticker', period = '1d', start = '2019-01-01')
# Out:
# [*********************100%***********************]  18 of 18 completed

# %%
companies
# Out:
#             DIDI                                                 NIO  \
#             Open   High   Low Close Adj Close      Volume       Open
# Date
# 2018-12-31   NaN    NaN   NaN   NaN       NaN         NaN   6.560000
# 2019-01-02   NaN    NaN   NaN   NaN       NaN         NaN   6.130000
# 2019-01-03   NaN    NaN   NaN   NaN       NaN         NaN   6.100000
# 2019-01-04   NaN    NaN   NaN   NaN       NaN         NaN   6.190000
# 2019-01-07   NaN    NaN   NaN   NaN       NaN         NaN   6.410000
# ...          ...    ...   ...   ...       ...         ...        ...
# 2021-11-23  8.14  8.327  8.05  8.12      8.12  13077200.0  41.500000
# 2021-11-24  8.11  8.210  8.02  8.11      8.11   8025900.0  41.700001
# 2021-11-26  7.67  7.920  7.50  7.88      7.88  30334700.0  39.400002
# 2021-11-29  7.87  7.950  7.58  7.81      7.81  24526000.0  40.849998
# 2021-11-30  7.67  7.830  7.24  7.63      7.63  29342400.0  40.369999
#
#                                              ...  TELL                  \
#                  High        Low      Close  ...   Low Close Adj Close
# Date                                         ...
# 2018-12-31   6.570000   6.210000   6.370000  ...  6.69  6.95      6.95
# 2019-01-02   6.240000   6.000000   6.200000  ...  6.66  7.11      7.11
# 2019-01-03   6.150000   6.020000   6.050000  ...  7.05  7.14      7.14
# 2019-01-04   6.400000   6.130000   6.360000  ...  7.15  7.40      7.40
# 2019-01-07   6.590000   6.310000   6.500000  ...  7.41  7.81      7.81
# ...               ...        ...        ...  ...   ...   ...       ...
# 2021-11-23  43.119999  40.470001  42.040001  ...  3.40  3.55      3.55
# 2021-11-24  42.509998  40.889999  41.419998  ...  3.44  3.55      3.55
# 2021-11-26  40.340000  39.099998  39.990002  ...  3.15  3.33      3.33
# 2021-11-29  41.200001  39.490002  40.459999  ...  3.22  3.35      3.35
# 2021-11-30  41.419998  38.349998  39.130001  ...  3.07  3.26      3.26
#
#                           RDS-B                                              \
#               Volume       Open       High        Low      Close  Adj Close
# Date
# 2018-12-31   1381500  60.000000  60.430000  59.660000  59.939999  58.226818
# 2019-01-02   1476000  59.349998  61.080002  59.119999  60.799999  59.062237
# 2019-01-03   1867400  60.750000  61.009998  60.080002  60.759998  59.023380
# 2019-01-04   1536400  61.380001  62.279999  61.320000  62.220001  60.441654
# 2019-01-07   2573200  61.520000  62.270000  61.320000  62.000000  60.227940
# ...              ...        ...        ...        ...        ...        ...
# 2021-11-23   8668400  43.500000  44.340000  43.480000  44.259998  44.259998
# 2021-11-24   5072700  43.700001  44.500000  43.680000  44.380001  44.380001
# 2021-11-26  12946500  41.799999  42.080002  41.369999  42.000000  42.000000
# 2021-11-29   8214400  43.110001  43.380001  42.380001  42.459999  42.459999
# 2021-11-30  17068200  41.790001  42.250000  41.509998  42.060001  42.060001
#
#
#              Volume
# Date
# 2018-12-31  2416900
# 2019-01-02  2133800
# 2019-01-03  1686600
# 2019-01-04  1917300
# 2019-01-07  1563300
# ...             ...
# 2021-11-23  2894200
# 2021-11-24  1981100
# 2021-11-26  2773900
# 2021-11-29  2332400
# 2021-11-30  3538900
#
# [736 rows x 108 columns]

# %%
companies['BABA'].plot()

# %% [markdown]
# ### The items to look at the
#
# * Bank debt at liabilities >>  should be decreasing
# * Cash in Current assets >> should be increasing
#
# NOTE: Current assets are any assets that can be converted into cash within a period of one year
#
# * Retained earnings "profit from one year is invested"  >> better to be increasing
#
# NOTE: Retained earnings (RE) is the amount of net income left over for the business after it has paid out dividends to its shareholders. A growth-focused company may not pay dividends at all or pay very small amounts because it may prefer to use the retained earnings to finance expansion activities. One way to assess how successful a company was in using the retained money is to look at a key factor called retained earnings to market value. It is calculated over a period of time (usually a couple of years) and assesses the change in stock price against the net earnings retained by the company.
#
# For example, during the period between September 2016 and September 2020, Apple Inc.'s (AAPL) stock price rose from $28.18 to $112.28 per share.1
#
#  During the same period, the total earnings per share (EPS) was $13.61, while the total dividend paid out by the company was $3.38 per share.
#  The difference between total EPS and total dividend gives the net earnings retained by the company: $13.61 - $3.38 = $10.23. That is, over the period, the company retained a total of $10.23 earnings per share.
#
# Over the same duration, its stock price rose by ($112.28 - $28.18 = $84.10) per share. Dividing this price rise per share by net earnings retained per share gives a factor of ($84.10 / $10.23 = 8.22), which indicates that for each dollar of retained earnings, the company managed to create $8.22 worth of market value.
#
# Generally speaking, a company with a negative retained earnings balance would signal weakness because it indicates that the company has experienced losses in one or more previous years.
#
# high retained earnings could indicate financial strength since it demonstrates a track record of profitability in previous years. On the other, it could also indicate that the company’s management is struggling to find profitable investment opportunities
#
# * Equity (Book Value per share) = (total assets + retained earnings) divided by the total number of stocks
#
# The book value per share (BVPS) metric can be used by investors to gauge whether a stock price is undervalued by comparing it to the firm's market value per share. If a company’s BVPS is higher than its market value per share—its current stock price—then the stock is considered undervalued. If the firm's BVPS increases, the stock should be perceived as more valuable, and the stock price should increase.
#
# Market Value Per Share vs. Book Value Per Share
#
#
# While BVPS is calculated using historical costs, the market value per share is a forward-looking metric that takes into account a company's future earning power.
#
# * Net revenue = the revenue a company earns in a given period.
# * Total costs = the total expenditure incurred to produce some type of output
# * profit = net revenue - cost
# * Net income = profit - tax = earnings before tax - tax
# *

# %% [markdown]
# ## Company analysis
